# %% [markdown]
# <a href="https://colab.research.google.com/github/ted-chang80/AIFFEL_quest_eng/blob/main/LLM_Application/LLM05/Day4_AgenticAI_Code_2_Langgraph_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langgraph langchain-openai langchain-core langchain-community langchain-experimental fpdf pdfplumber
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.3.1)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.2-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (1.4.0)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.7.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.37.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.7-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.14.1)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.49)
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.8.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (48.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.5.20)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (3.0)
# Downloading langchain_openai-1.2.2-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 11.5 MB/s eta 0:00:00
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 63.6 MB/s eta 0:00:00
# Downloading langchain_experimental-0.4.2-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 22.1 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.5 MB/s eta 0:00:00
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 135.0 MB/s eta 0:00:00
# Downloading langchain_classic-1.0.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.6 MB/s eta 0:00:00
# Downloading pypdfium2-5.8.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 124.2 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.7 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=b394bd287c89a7179be4f6920a7828650c366b46639a24b52b873424605ab21a
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# Installing collected packages: fpdf, requests, pypdfium2, pdfminer.six, pdfplumber, langchain-text-splitters, langchain-openai, langchain-classic, langchain-community, langchain-experimental
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed fpdf-1.7.2 langchain-classic-1.0.7 langchain-community-0.4.2 langchain-experimental-0.4.2 langchain-openai-1.2.2 langchain-text-splitters-1.1.2 pdfminer.six-20251230 pdfplumber-0.11.9 pypdfium2-5.8.0 requests-2.34.2

# %%
from langchain_core.runnables import RunnableConfig
from langchain_core.messages import AIMessage
from typing import Annotated, Literal
from typing_extensions import TypedDict
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.prompts import PromptTemplate
from langchain_core.tools import tool
from langchain_community.agent_toolkits import FileManagementToolkit
from langchain_experimental.tools.python.tool import PythonAstREPLTool
from pydantic import BaseModel, Field
from fpdf import FPDF
import random
import pdfplumber
import os
import requests
import warnings

warnings.filterwarnings("ignore")
# Out:
# /tmp/ipykernel_3731/3254521282.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# /tmp/ipykernel_3731/3254521282.py:13: DeprecationWarning: `langchain-experimental` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-experimental/issues/87 for details.
#   from langchain_experimental.tools.python.tool import PythonAstREPLTool

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - [TAVILY](https://www.tavily.com/)는 LLM 모델의 웹서치 기능을 붙여주는 대표적인 API 서비스

# %%
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_KEY')
os.environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')

# %%
# 그래프 상태 정의

class State(TypedDict):
    query : Annotated[str, "User Question"]
    answer : Annotated[str, "LLM response"]
    messages : Annotated[list, add_messages]
    tool_call : Annotated[dict, "Tool Call Result"]

# %%
# LLM 정의
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o",
                             temperature=0)

# %%
@tool
def read_pdf(file_path: str):
    """
    PDF 파일에서 텍스트를 추출하는 도구입니다.
    표 형식 또는 일반 텍스트가 포함된 PDF를 읽고 문자열로 반환합니다.

    file_path 예시: './report.pdf'
    """
    try:
        text = ""
        with pdfplumber.open(file_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
        return text.strip() if text.strip() else "❌ PDF에서 텍스트를 추출할 수 없습니다."
    except Exception as e:
        return f"❌ PDF 읽기 오류: {str(e)}"

# %%
@tool
def write_pdf(content: str, filename: str = "output.pdf", summary: bool =True):
    """
    텍스트를 PDF 파일로 저장하는 도구입니다.
    PDF형태의 문서로 만들어야할 때 이 도구를 사용하세요.
    """

    if summary:
        prompt = PromptTemplate.from_template("""
                당신은 보고서를 작성하는 어시스턴트입니다. 당신에겐 문서 모음이 제공되고 이를 잘 분석하여 보고서를 작성하여야 합니다.
                아래의 content는 문서 모음입니다. 문서의 제목, 본문을 잘 판단하고 정리하여 요약합니다.
                항상 구조화된 출력을 제공하세요.
                항상 마지막엔 인사이트도 첨부합니다.

                content : {content}
                """)

        chain = prompt | llm

        content = chain.invoke({"content":content}).content

    else:
        pass

    font_url = "https://github.com/google/fonts/raw/main/ofl/notosanskr/NotoSansKR%5Bwght%5D.ttf"
    font_path = "./fonts/NotoSansKR.ttf"

    try:
        os.mkdir("./fonts/")
        response = requests.get(font_url)
        with open(font_path, "wb") as f:
            f.write(response.content)
    except:
        pass

    pdf = FPDF()
    pdf.add_page()
    pdf.set_auto_page_break(auto=True, margin=15)

    font_path = "./fonts/NotoSansKR.ttf"  # <-- 여기에 실제 폰트 파일이 있어야 함

    try:
        pdf.add_font("NotoSans", "", font_path, uni=True)
        pdf.set_font("NotoSans", size=12)
    except:
        raise ValueError("한글 폰트를 등록할 수 없습니다.")

    for line in content.split("\n"):
        pdf.multi_cell(0, 10, line)
    pdf.output(f"./{filename}")

    return f"{filename} 저장 완료"

# %%
# 툴 정의
# TavilySearchResults : 웹 검색 도구
# PythonAstREPLTool : 파이썬 코드 실행 도구
# write_pdf : pdf 생성 도구
# read_pdf : pdf 읽기 도구
# file_delete : 파일 삭제 도구
# list_directory : 파일 목록 읽기 도구

tools = [TavilySearchResults(max_results=10), PythonAstREPLTool(), write_pdf, read_pdf, *FileManagementToolkit(
                                                                            selected_tools=["file_delete","list_directory"]).get_tools()]
search_tool, code_tool, write_tool, read_tool, delete_tool, listdir_tool= tools

# %%
# PDF 쓰기 도구 예시

write_tool.invoke({"content":"안녕하세요! \nLanggraph 예제코드입니다.", "filename":"Langgraph_report.pdf", "summary":False})
# Out:
# 'Langgraph_report.pdf 저장 완료'

# %%
# PDF 읽기 도구 예시

print("\n\n", read_tool.invoke("/content/Langgraph_report.pdf"))
# Out:
#  안녕하세요!
# Langgraph 예제코드입니다.

# %%
# 파일 목록 도구 예시

print(listdir_tool.invoke(input=""))
# Out:
# .config
# drive
# Langgraph_report.pdf
# fonts
# sample_data

# %%
# 삭제 도구 예시

delete_tool.invoke("Langgraph_report.pdf")
# Out:
# 'File deleted successfully: Langgraph_report.pdf.'

# %%
# LLM에게 도구 할당

llm_with_tools = llm.bind_tools(tools)

# %%
# 전체 메시지 중 마지막 메시지를 제외하고 최대 8개까지 단기 기억(history)으로 추출

def shorterm_memory(state:State):

    if len(state["messages"]) > 8:
        history = state["messages"][-8:-1]
    elif len(state["messages"]) == 1:
        history = ""
    else:
        history = state["messages"][:-1]

    return history

# %%
class HistoryChecker(BaseModel):
    """
    이전의 대화 기록을 참고하여 질문에 대해 답변할 수 있는지 판단합니다.
    답변할 수 있다면 "yes", 답변할 수 없다면 "no"를 반환합니다.
    """

    yes_no : Literal["yes", "no"] = Field(..., description="""Use your previous conversation history to determine if you can answer your questions.
    Return "yes" if you can answer, "no" if you can't answer.""")

# %%
# 히스토리 기반 답변 분기를 위한 함수 설정

def history_check(state:State):

    prompt = PromptTemplate.from_template("""

                이전의 대화 기록을 참고하여 질문에 대해 답변할 수 있는지 판단합니다.
                답변할 수 있다면 "yes", 답변할 수 없다면 "no"를 반환합니다.

                대화 기록 : {history}

                질문 : {query}

                """)

    chain = prompt | history_checker

    history = shorterm_memory(state)

    result = chain.invoke({"history":history,
                            "query":state["query"]})

    return result.yes_no

# %%
# LLM의 응답을 HistoryChecker 클래스 구조에 맞춰 파싱하도록 설정

history_checker = llm.with_structured_output(HistoryChecker)

# %%
# 기억 기반 답변 노드

def memory_chat(state:State):

    prompt = PromptTemplate.from_template("""

                이전의 대화 기록을 참고하여 질문에 대해 답변하세요.
                아래 대화 기록을 첨부합니다.
                대화 기록을 통해 답변이 어렵다면 내부 지식을 참조하세요.

                대화 기록 : {history}

                질문 : {query}

                """)


    chain = prompt | llm

    history = shorterm_memory(state)

    result = chain.invoke({"history":history,
                           "query":state["query"]})

    if len(state["tool_call"]) == 0:
        return {"answer":result.content,
                "messages":result,
                "tool_call":"사용된 기록 없음."}
    else:
        return {"answer":result.content,
                "messages":result}

# %%
# 기억 기반 답변 분기 노드

def history_node(state:State):
    if len(state["messages"]) == 1:
        return {"answer":"답변 없음",
                "tool_call":"사용된 도구 없음"}
    else:
        return state

# %%
# 도구 선택 노드

def select(
    state: State,
):

    prompt = PromptTemplate.from_template("""

                이전의 대화 기록을 참고하여 질문에 대해 답변하세요.
                아래 대화 기록을 첨부합니다.
                이전의 대화가 다음에 어떤 도구를 사용해야하는지 힌트가 될 수 있습니다. 꼭 참조하세요.
                도구의 변화가 큰 결과를 가져올 수 있습니다.
                들어온 메시지, 정답, 이전 기록을 모두 분석하여 가장 적절한 도구를 선택하세요.

                대화 기록 : {history}

                최근 사용한 도구 : {tool_name}

                정답 : {answer}

                질문 : {query}

                """)

    chain = prompt | llm_with_tools

    history = shorterm_memory(state)

    result = chain.invoke({"history" : history,
                           "tool_name" : state["tool_call"],
                            "answer": state["answer"],
                            "query": state["query"]})

    if hasattr(result, "tool_calls") and len(result.tool_calls) > 0:
        tool_calls = result.tool_calls

        return {"messages": result,
                "tool_call":tool_calls}
    else:
        return {"messages":AIMessage(content=f"""도구를 선택하지 못했습니다. 적절한 도구를 재선택하세요.
                                        """),
                                    "tool_call":"선택된 도구 없음"}

# %%
# 도구 실행 노드

tool_node = ToolNode(tools)

# %%
class AnswerChecker(BaseModel):
    """
    정답 분류기입니다.

    정답이 질문을 해결했는지 여부를 판단합니다.
    질문을 해결하지 못했을 시 해결될 때까지 도구를 이용합니다.

    질문을 해결했다면 "end", 해결하지 못했다면 "tool"을 반환합니다.
    """


    end : Literal["end", "tool"] = Field(..., description="""You are the answer sorter.

                                                                Determine if the correct answer has solved the question.
                                                                If the question is not resolved, use the tool until it is resolved.

                                                                Return "end" if you solved the question, or "tool" if you didn't.""")

# %%
# LLM의 응답을 AnswerChecker 클래스 구조에 맞춰 파싱하도록 설정

answer_checker = llm.with_structured_output(AnswerChecker)

# %%
# 답변 확인 노드

def response(state:State):

    return {"answer":state["messages"][-1]}

# %%
# 답변 완성 판단 분기 함수

def answer_check(state:State):

    prompt = PromptTemplate.from_template("""
    당신은 정답 분류기 어시스턴트입니다.

    정답이 질문을 해결하였는지 여부를 판단합니다.
    질문을 해결하지 못했다면 도구를 이용합니다.

    질문을 해결하였다면 "end", 아니라면 "tool"을 반환합니다.

    기존 History도 참고하여 답변하세요.

    History : {history}

    정답 : {answer}

    질문 : {query}
    """)

    chain = prompt | answer_checker

    history = shorterm_memory(state)

    result = chain.invoke({"history" : history,
                            "answer": state["answer"],
                            "query": state["query"]})

    return result.end

# %%
# 그래프 정의

graph_builder = StateGraph(State)

# %%
# 노드 및 엣지 정의

graph_builder.add_node("history_node", history_node)
graph_builder.add_node("memory_chat", memory_chat)
graph_builder.add_node("select", select)
graph_builder.add_node("tools", tool_node)
graph_builder.add_node("response", response)


graph_builder.add_edge(START, "history_node")
graph_builder.add_conditional_edges("history_node",
                            history_check,
                            {"yes":"memory_chat",
                             "no":"select"})
graph_builder.add_edge("select", "tools")
graph_builder.add_edge("tools", "response")
graph_builder.add_edge("memory_chat", "response")
graph_builder.add_conditional_edges("response",
                                    answer_check,
                                    {"end":END,
                                    "tool":"select"});

# %%
# 메모리 설정 및 그래프 컴파일

memory = MemorySaver()

graph = graph_builder.compile(checkpointer=memory)

# %%
# 그래프 시각화
# 가끔 "ReadTimeout: HTTPSConnectionPool(host='mermaid.ink', port=443): Read timed out. (read timeout=10)"라는 에러가 발생
# 시간 초과로 그래프 생성에 실패했다는 메시지일뿐 기능과는 관계없으니 진행해도 괜찮습니다.

graph

# %%
# config 재생성 노드, config의 재사용은 고려되지 않음. 재사용한다면 변수에 할당하여 사용할 것

def reset_config(limit=20):

    thread_id=random.randint(1,999999)

    config = RunnableConfig(recursion_limit=limit, configurable={"thread_id": thread_id})

    return config

# %%
# 출력 함수 정의
# mode = "values" : 상태의 키, 값의 형태로 반환
# mode = "updates" : 업데이트되는 값만 반환

def streaming(query, config, mode="values"):

    result = graph.stream({"messages":("user", query),
                         "query":query}, config=config, stream_mode=mode)

    if mode == "values":
        for step in result:
            for k, v in step.items():
                if k == "messages":
                    v[-1].pretty_print()
    elif mode == "updates":
        for step in result:
            for k,v in step.items():
                print(f"\n\n=== {k} ===\n\n")
                print(v)

    return

# %%
config = reset_config()

query = "1+1은 뭔가요?"

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 1+1은 뭔가요?
# ================================ Human Message =================================
#
# 1+1은 뭔가요?
# ================================== Ai Message ==================================
#
# 1+1은 2입니다.
# ================================== Ai Message ==================================
#
# 1+1은 2입니다.

# %%
config = reset_config()

query = "현대자동차라는 회사에 대해 조사해주세요. 잘 정리된 보고서를 제공해주십시오. pdf 포멧의 파일로 받기를 희망합니다."

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 현대자동차라는 회사에 대해 조사해주세요. 잘 정리된 보고서를 제공해주십시오. pdf 포멧의 파일로 받기를 희망합니다.
# ================================ Human Message =================================
#
# 현대자동차라는 회사에 대해 조사해주세요. 잘 정리된 보고서를 제공해주십시오. pdf 포멧의 파일로 받기를 희망합니다.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_Cp9GCKHv1gOBSiepetTh8ZPG)
#  Call ID: call_Cp9GCKHv1gOBSiepetTh8ZPG
#   Args:
#     query: Hyundai Motor Company overview 2023
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Hyundai Motor Announces 2023 Q4 Business Results", "url": "https://www.hyundai.news/eu/articles/press-releases/hyundai-motor-announces-2023-q4-business-results.html", "content": "Press material\n\nHyundai Motor Company today announced its 2023 annual and fourth quarter business results. Last year, the company sold 4,216,898 vehicles worldwide, up 7 percent from 2022. Annual revenue increased 14.4 percent to KRW 162.7 trillion.\n\nAnnual operating profit climbed 54 percent to KRW 15.12 trillion, with an operating profit margin of 9.3 percent. Hyundai Motor recorded an annual net profit of KRW 12.27 trillion, up 54 percent year over year. [...] 2023 annual vehicle sales increased 7% to 4.22 million units\n  + Annual revenue was up 14.4% to KRW 162.7 trillion\n  + Operating profit rose 54% to KRW 15.12 trillion; operating profit margin hit 9.3%\n  + Net profit climbed 54% to KRW 12.27 trillion\n  + Increased sales volume, enhanced product mix and favorable exchange rate helped the company achieve solid results\n Q4 2023 sales volume stood at 1.09 million units, up 4.9% year over year\n  + Revenue increased 8.3% Y/y to KRW 41.67 trillion\n  + Operating profit was up slightly to KRW 3.41 trillion from a year earlier; Q4 operating profit margin was 8.2%\n  + Q4 net profit increased 28.8% Y/y to KRW 2.2 trillion\n Hyundai Motor raised the 2023 year-end dividend to KRW 8,400\n  + Annual dividend increased 63% from a year earlier to KRW 11,400 [...] In the fourth quarter of 2023, Hyundai Motor sold 1,089,862 units around the globe. Sales in markets outside of Korea were up by 5.3 percent to 891,304 units, backed by strong demand in North America, Europe and India. Sales in Korea increased 3.4 percent to 198,558 units, fueled by strong demand for the all-new SANTA FE SUV, as well as other SUV models.\n\nOver the period from October to December 2023, global electrified vehicle sales (including commercial vehicles) increased 27.7 percent year over year to 173,297 units, driven by a stronger hybrid lineup and sales growth of Hyundai’s dedicated electric vehicle (EV) brand, IONIQ.", "score": 0.88178825}, {"title": "[PDF] Annual Report 2023 - Hyundai Motor Manufacturing Czech", "url": "https://www.hyundai-motor.cz/wp-content/uploads/2024/06/VZ_Hyundai_2023_EN_final.pdf", "content": "company in the TOP 10. ● \u0007 1st place in the Sodexo Employer of the Year in the Moravian-Silesian Region and 4th place in the Czech Republic in the category of companies with up to 5,000 employees. ● \u0007 Health Promoting Enterprise III award in the category of more than 250 employees. ● \u0007 Winners in the Automotive Business of the Year competition in the category of more than 250 employees. ● \u0007 Moravian-Silesian Region Governor’s Award for Corporate Social Responsibility – 1st place in the category of business entities with more than 250 employees. Awards overview of HMMC cars in 2023: New KONA Electric: ● \u0007 Auto Express – UK – \u0007 Car of the Year – \u0007 Small Company Car of the Year – \u0007 Small SUV of the Year TUCSON: ● \u0007 Auto Express – UK – \u0007 Mid-Size SUV of the Year Annual Report 2023 Hyundai [...] In 2008, the Company began the production of cars and transmissions, which constitute the Company’s key production programme. In 2023, the Company manu­ factured three models: Hyundai Tucson, Hyundai Kona Electric and the third-generation Hyundai i30, which is produced in three versions: five-door hatchback, wagon and fastback. The sports version of the five-door hatch­ back is manufactured under the name Hyundai i30 N and the sports version of the fastback under the name Hyun­ dai i30 fastback N. In August 2023, production of the first version of the Kona Electric was discontinued and pro­ duction of the next generation model was launched. [...] The Plant’s Area 200 ha Built Up Area 28.3 ha Total Investment EUR 1.98 billion Number of Employees 3,222 (including agency employees) Share of Czech Citizens 93% Male/ fem ...
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Hyundai Motor Announces 2023 Q4 Business Results", "url": "https://www.hyundai.news/eu/articles/press-releases/hyundai-motor-announces-2023-q4-business-results.html", "content": "Press material\n\nHyundai Motor Company today announced its 2023 annual and fourth quarter business results. Last year, the company sold 4,216,898 vehicles worldwide, up 7 percent from 2022. Annual revenue increased 14.4 percent to KRW 162.7 trillion.\n\nAnnual operating profit climbed 54 percent to KRW 15.12 trillion, with an operating profit margin of 9.3 percent. Hyundai Motor recorded an annual net profit of KRW 12.27 trillion, up 54 percent year over year. [...] 2023 annual vehicle sales increased 7% to 4.22 million units\n  + Annual revenue was up 14.4% to KRW 162.7 trillion\n  + Operating profit rose 54% to KRW 15.12 trillion; operating profit margin hit 9.3%\n  + Net profit climbed 54% to KRW 12.27 trillion\n  + Increased sales volume, enhanced product mix and favorable exchange rate helped the company achieve solid results\n Q4 2023 sales volume stood at 1.09 million units, up 4.9% year over year\n  + Revenue increased 8.3% Y/y to KRW 41.67 trillion\n  + Operating profit was up slightly to KRW 3.41 trillion from a year earlier; Q4 operating profit margin was 8.2%\n  + Q4 net profit increased 28.8% Y/y to KRW 2.2 trillion\n Hyundai Motor raised the 2023 year-end dividend to KRW 8,400\n  + Annual dividend increased 63% from a year earlier to KRW 11,400 [...] In the fourth quarter of 2023, Hyundai Motor sold 1,089,862 units around the globe. Sales in markets outside of Korea were up by 5.3 percent to 891,304 units, backed by strong demand in North America, Europe and India. Sales in Korea increased 3.4 percent to 198,558 units, fueled by strong demand for the all-new SANTA FE SUV, as well as other SUV models.\n\nOver the period from October to December 2023, global electrified vehicle sales (including commercial vehicles) increased 27.7 percent year over year to 173,297 units, driven by a stronger hybrid lineup and sales growth of Hyundai’s dedicated electric vehicle (EV) brand, IONIQ.", "score": 0.88178825}, {"title": "[PDF] Annual Report 2023 - Hyundai Motor Manufacturing Czech", "url": "https://www.hyundai-motor.cz/wp-content/uploads/2024/06/VZ_Hyundai_2023_EN_final.pdf", "content": "company in the TOP 10. ● \u0007 1st place in the Sodexo Employer of the Year in the Moravian-Silesian Region and 4th place in the Czech Republic in the category of companies with up to 5,000 employees. ● \u0007 Health Promoting Enterprise III award in the category of more than 250 employees. ● \u0007 Winners in the Automotive Business of the Year competition in the category of more than 250 employees. ● \u0007 Moravian-Silesian Region Governor’s Award for Corporate Social Responsibility – 1st place in the category of business entities with more than 250 employees. Awards overview of HMMC cars in 2023: New KONA Electric: ● \u0007 Auto Express – UK – \u0007 Car of the Year – \u0007 Small Company Car of the Year – \u0007 Small SUV of the Year TUCSON: ● \u0007 Auto Express – UK – \u0007 Mid-Size SUV of the Year Annual Report 2023 Hyundai [...] In 2008, the Company began the production of cars and transmissions, which constitute the Company’s key production programme. In 2023, the Company manu­ factured three models: Hyundai Tucson, Hyundai Kona Electric and the third-generation Hyundai i30, which is produced in three versions: five-door hatchback, wagon and fastback. The sports version of the five-door hatch­ back is manufactured under the name Hyundai i30 N and the sports version of the fastback under the name Hyun­ dai i30 fastback N. In August 2023, production of the first version of the Kona Electric was discontinued and pro­ duction of the next generation model was launched. [...] The Plant’s Area 200 ha Built Up Area 28.3 ha Total Investment EUR 1.98 billion Number of Employees 3,222 (including agency employees) Share of Czech Citizens 93% Male/ fem ...
# ================================== Ai Message ==================================
# Tool Calls:
#   write_pdf (call_xNeyr3CYuItn4muS8lQmNS3R)
#  Call ID: call_xNeyr3CYuItn4muS8lQmNS3R
#   Args:
#     content: ### Hyundai Motor Company Overview
#
# **Introduction**
# Hyundai Motor Company, established in 1967, is a South Korean multinational automotive manufacturer headquartered in Seoul, South Korea. It is part of the Hyundai Motor Group, which also includes Kia Motors and Genesis Motors.
#
# **Business Operations**
# Hyundai operates the world's largest integrated automobile manufacturing facility in Ulsan, South Korea, which has an annual production capacity of 1.6 million units. The company employs about 70,000 people worldwide and sells vehicles in 193 countries through some 5,000 dealerships and showrooms.
#
# **Financial Performance (2023)**
# - **Vehicle Sales**: Hyundai sold 4,216,898 vehicles worldwide, marking a 7% increase from the previous year.
# - **Revenue**: The company reported an annual revenue of KRW 162.7 trillion, a 14.4% increase year-over-year.
# - **Operating Profit**: Hyundai's operating profit rose by 54% to KRW 15.12 trillion, with an operating profit margin of 9.3%.
# - **Net Profit**: The net profit for the year was KRW 12.27 trillion, up 54% from the previous year.
#
# **Key Developments**
# - Hyundai has been focusing on expanding its electric vehicle lineup, with significant sales growth in its dedicated EV brand, IONIQ.
# - The company has established a joint venture with LG Energy Solution to manufacture electric vehicle batteries in the US.
# - Hyundai is also investing in sustainable technologies like hydrogen fuel cells to transition to greener options.
#
# **Awards and Recognition**
# - Hyundai Motor was named one of the 'World's Best Companies 2025' by TIME, reflecting its strong performance in employee satisfaction, revenue growth, and ESG initiatives.
#
# **Future Outlook**
# Hyundai aims to continue its transformation into a Smart Mobility Solution Provider, investing in advanced technologies such as robotics and Advanced Air Mobility (AAM). The company is committed to introducing zero-emission vehicles and enhancing its global product mix to focus on high-value models.
#
# **Conclusion**
# Hyundai Motor Company continues to be a leader in the automotive industry, with a strong focus on innovation, sustainability, and global expansion. Its strategic investments and commitment to quality and customer satisfaction position it well for future growth.
#     filename: Hyundai_Motor_Company_Report.pdf
# ================================= Tool Message =================================
# Name: write_pdf
#
# Hyundai_Motor_Company_Report.pdf 저장 완료
# ================================= Tool Message =================================
# Name: write_pdf
#
# Hyundai_Motor_Company_Report.pdf 저장 완료

# %%
query = "현대자동차의 경쟁사에 대한 정보도 정리된 보고서를 작성해주세요."

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 현대자동차의 경쟁사에 대한 정보도 정리된 보고서를 작성해주세요.
# ================================ Human Message =================================
#
# 현대자동차의 경쟁사에 대한 정보도 정리된 보고서를 작성해주세요.
# ================================== Ai Message ==================================
#
# 현대자동차의 경쟁사에 대한 정보를 정리한 보고서를 작성하겠습니다. 현대자동차는 글로벌 자동차 시장에서 여러 주요 기업들과 경쟁하고 있습니다. 주요 경쟁사로는 다음과 같은 기업들이 있습니다:
#
# ### 1. **도요타 자동차 (Toyota Motor Corporation)**
# - **본사**: 일본 아이치현
# - **주요 제품**: 승용차, 하이브리드 차량, 전기차, 상용차
# - **특징**: 도요타는 하이브리드 기술의 선두주자로, 프리우스(Prius) 모델로 유명합니다. 지속 가능한 이동 수단 개발에 집중하고 있으며, 수소 연료 전지 차량에도 투자하고 있습니다.
#
# ### 2. **폭스바겐 그룹 (Volkswagen Group)**
# - **본사**: 독일 볼프스부르크
# - **주요 제품**: 승용차, 상용차, 전기차
# - **특징**: 폭스바겐은 다양한 브랜드(아우디, 포르쉐, 스코다 등)를 보유하고 있으며, 전기차 플랫폼인 MEB를 통해 전기차 시장에서의 입지를 강화하고 있습니다.
#
# ### 3. **제너럴 모터스 (General Motors)**
# - **본사**: 미국 디트로이트
# - **주요 제품**: 승용차, 트럭, 전기차
# - **특징**: GM은 전기차 브랜드인 쉐보레 볼트(Bolt)와 GMC 허머 EV를 통해 전기차 시장에 진출하고 있으며, 자율주행 기술 개발에도 적극적입니다.
#
# ### 4. **포드 모터 컴퍼니 (Ford Motor Company)**
# - **본사**: 미국 미시간주 디어본
# - **주요 제품**: 승용차, 트럭, 전기차
# - **특징**: 포드는 전기차 모델인 머스탱 마하-E와 F-150 라이트닝을 통해 전기차 시장에서의 경쟁력을 강화하고 있습니다.
#
# ### 5. **혼다 자동차 (Honda Motor Co., Ltd.)**
# - **본사**: 일본 도쿄
# - **주요 제품**: 승용차, 오토바이, 전기차
# - **특징**: 혼다는 하이브리드 및 전기차 기술 개발에 집중하고 있으며, 수소 연료 전지 차량 개발에도 참여하고 있습니다.
#
# ### 6. **BMW 그룹 (BMW Group)**
# - **본사**: 독일 뮌헨
# - **주요 제품**: 승용차, 전기차, 오토바이
# - **특징**: BMW는 프리미엄 전기차 시장에서의 입지를 강화하고 있으며, i 시리즈를 통해 전기차 라인업을 확장하고 있습니다.
#
# ### 결론
# 현대자동차는 이러한 글로벌 경쟁사들과 다양한 분야에서 경쟁하고 있으며, 특히 전기차 및 친환경 기술 개발에 집중하여 시장에서의 경쟁력을 강화하고 있습니다. 현대자동차는 지속 가능한 이동 수단과 혁신적인 기술 개발을 통해 글로벌 시장에서의 입지를 더욱 확고히 하고자 합니다.
#
# 이 보고서를 PDF로 저장하여 제공할 수 있습니다. 필요하시면 말씀해 주세요.
# ================================== Ai Message ==================================
#
# 현대자동차의 경쟁사에 대한 정보를 정리한 보고서를 작성하겠습니다. 현대자동차는 글로벌 자동차 시장에서 여러 주요 기업들과 경쟁하고 있습니다. 주요 경쟁사로는 다음과 같은 기업들이 있습니다:
#
# ### 1. **도요타 자동차 (Toyota Motor Corporation)**
# - **본사**: 일본 아이치현
# - **주요 제품**: 승용차, 하이브리드 차량, 전기차, 상용차
# - **특징**: 도요타는 하이브리드 기술의 선두주자로, 프리우스(Prius) 모델로 유명합니다. 지속 가능한 이동 수단 개발에 집중하고 있으며, 수소 연료 전지 차량에도 투자하고 있습니다.
#
# ### 2. **폭스바겐 그룹 (Volkswagen Group)**
# - **본사**: 독일 볼프스부르크
# - **주요 제품**: 승용차, 상용차, 전기차
# - **특징**: 폭스바겐은 다양한 브랜드(아우디, 포르쉐, 스코다 등)를 보유하고 있으며, 전기차 플랫폼인 MEB를 통해 전기차 시장에서의 입지를 강화하고 있습니다.
#
# ### 3. **제너럴 모터스 (General Motors)**
# - **본사**: 미국 디트로이트
# - **주요 제품**: 승용차, 트럭, 전기차
# - **특징**: GM은 전기차 브랜드인 쉐보레 볼트(Bolt)와 GMC 허머 EV를 통해 전기차 시장에 진출하고 있으며, 자율주행 기술 개발에도 적극적입니다.
#
# ### 4. **포드 모터 컴퍼니 (Ford Motor Company)**
# - **본사**: 미국 미시간주 디어본
# - **주요 제품**: 승용차, 트럭, 전기차
# - **특징**: 포드는 전기차 모델인 머스탱 마하-E와 F-150 라이트닝을 통해 전기차 시장에서의 경쟁력을 강화하고 있습니다.
#
# ### 5. **혼다 자동차 (Honda Motor Co., Ltd.)**
# - **본사**: 일본 도쿄
# - **주요 제품**: 승용차, 오토바이, 전기차
# - **특징**: 혼다는 하이브리드 및 전기차 기술 개발에 집중하고 있으며, 수소 연료 전지 차량 개발에도 참여하고 있습니다.
#
# ### 6. **BMW 그룹 (BMW Group)**
# - **본사**: 독일 뮌헨
# - **주요 제품**: 승용차, 전기차, 오토바이
# - **특징**: BMW는 프리미엄 전기차 시장에서의 입지를 강화하고 있으며, i 시리즈를 통해 전기차 라인업을 확장하고 있습니다.
#
# ### 결론
# 현대자동차는 이러한 글로벌 경쟁사들과 다양한 분야에서 경쟁하고 있으며, 특히 전기차 및 친환경 기술 개발에 집중하여 시장에서의 경쟁력을 강화하고 있습니다. 현대자동차는 지속 가능한 이동 수단과 혁신적인 기술 개발을 통해 글로벌 시장에서의 입지를 더욱 확고히 하고자 합니다.
#
# 이 보고서를 PDF로 저장하여 제공할 수 있습니다. 필요하시면 말씀해 주세요.

# %%
#config = reset_config()

#query = "현재 폴더의 pdf로 이루어진 파일 모두 삭제해줘"

#streaming(query, config)

# %%
config = reset_config()

code = """
아래 코드 실행시켜주세요.

```python

result = 0

for i in range(20):
    print(f"{i+1}번째 출력: ", i+1)
    result += i

print("최종 결과: ", result)

```
"""

streaming(code, config)
# Out:
# ================================ Human Message =================================
#
#
# 아래 코드 실행시켜주세요.
#
# ```python
#
# result = 0
#
# for i in range(20):
#     print(f"{i+1}번째 출력: ", i+1)
#     result += i
#
# print("최종 결과: ", result)
#
# ```
#
# ================================ Human Message =================================
#
#
# 아래 코드 실행시켜주세요.
#
# ```python
#
# result = 0
#
# for i in range(20):
#     print(f"{i+1}번째 출력: ", i+1)
#     result += i
#
# print("최종 결과: ", result)
#
# ```
#
# ================================== Ai Message ==================================
# Tool Calls:
#   python_repl_ast (call_mBPGSezFyWIq5d69zTR6kFOd)
#  Call ID: call_mBPGSezFyWIq5d69zTR6kFOd
#   Args:
#     query: result = 0
#
# for i in range(20):
#     print(f"{i+1}번째 출력: ", i+1)
#     result += i
#
# print("최종 결과: ", result)
# 1번째 출력:  1
# 2번째 출력:  2
# 3번째 출력:  3
# 4번째 출력:  4
# 5번째 출력:  5
# 6번째 출력:  6
# 7번째 출력:  7
# 8번째 출력:  8
# 9번째 출력:  9
# 10번째 출력:  10
# 11번째 출력:  11
# 12번째 출력:  12
# 13번째 출력:  13
# 14번째 출력:  14
# 15번째 출력:  15
# 16번째 출력:  16
# 17번째 출력:  17
# 18번째 출력:  18
# 19번째 출력:  19
# 20번째 출력:  20
# ================================= Tool Message =================================
# Name: python_repl_ast
#
# 최종 결과:  190
#
# ================================= Tool Message =================================
# Name: python_repl_ast
#
# 최종 결과:  190

# %%
config = reset_config()

streaming("""
          모두의연구소는 어떤 곳이야?
          깔끔하게 정리해서 레포트로 만들어줘.
          레포트의 형식은 pdf로 저장해주면 돼.
          이름은 "모두의연구소_레포트.pdf"로 해줘.""", config)
# Out:
# ================================ Human Message =================================
#
#
#           모두의연구소는 어떤 곳이야?
#           깔끔하게 정리해서 레포트로 만들어줘.
#           레포트의 형식은 pdf로 저장해주면 돼.
#           이름은 "모두의연구소_레포트.pdf"로 해줘.
# ================================ Human Message =================================
#
#
#           모두의연구소는 어떤 곳이야?
#           깔끔하게 정리해서 레포트로 만들어줘.
#           레포트의 형식은 pdf로 저장해주면 돼.
#           이름은 "모두의연구소_레포트.pdf"로 해줘.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_yva2dPlUhjfA2SV0oiYaQZcp)
#  Call ID: call_yva2dPlUhjfA2SV0oiYaQZcp
#   Args:
#     query: 모두의연구소 소개
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "스토리 | 모두의연구소", "url": "https://modulabs.co.kr/modulabs-story", "content": "## 모두의연구소 미션 소개\n\nOur Mission\n\n### Share Value, Grow Together\n\n함께 지식을 공유하고 성장하는 연구 문화를 전파합니다\n\nOur Mission\n\nOur Value\n\n### 모두의연구소는 “경쟁이 아닌 상생의 힘” 을 믿습니다.\n\nOur Value\n\nbackground Quote\n\n모두의연구소는 지식을 나누고 함께 성장하는 커뮤니티형 교육을 통해 더 나은 미래를 만들고자 합니다. AI 시대, 100년 전처럼 주입식으로 가르치는 교육 방식은 점점 그 의미를 잃고 있습니다.   \n   \n 우리는 사람과 사람을 연결하여 함께 웃고, 배우고, 성장하는 과정을 소중히 여기며, 세상에 필요한 지식을 함께 나누는 세상을 꿈꿉니다.\n\n모두의연구소 대표 김승일\n\n브랜딩북 열어보기\n\n## 모두의연구소 비전 소개\n\n모두의연구소는\n\n### 오늘도 AI / SW 교육 혁신을 선도하고 있습니다\n\n 커뮤니티 연구원\n\n  커뮤니티 연구원\n\n  10,212\n\n  plus\n 스터디 활동 수\n\n  스터디 활동 수\n\n  949\n\n  plus\n 탑티어 논문\n\n  탑티어 논문\n\n  100\n\n  plus\n AI / SW 졸업생\n\n  AI / SW 졸업생\n\n  1,258\n\n  plus\n\n2024\n\n2024\n\n05\n\nAI 미래포럼 공동의장단 대표 선정\n\n12\n\n과학기술정보통신부 장관 표창\n\n2023\n\n2023\n\n09\n\n2023 직업능력의 달 기념 대통령 표창\n\n10\n\nSW교육 오름캠프 교육 런칭\n\n2022\n\n2022\n\n02\n\n70억 투자 유치 (KB인베스트먼트, 대교인베스트먼트)\n\n06 [...] 10\n\nAI 혁신학교 아이펠(AIFFEL) 온라인 캠퍼스 개소\n\n2021\n\n02\n\nAI 혁신학교 아이펠(AIFFEL) 인천 캠퍼스 개소\n\n10\n\nKOREA AI STARTUP 100 선정\n\n12\n\nAI 혁신학교 아이펠(AIFFEL) 부산, 울산, 대구 캠퍼스 개소\n\n2020\n\n07\n\nAI 혁신학교 아이펠(AIFFEL) 강남 캠퍼스 개소\n\n12\n\nAI 혁신학교 아이펠(AIFFEL) 대전 및 문래 캠퍼스 개소\n\n2017\n\n01\n\n모두의연구소 기업교육 시작\n\n10\n\n국내 최초 거꾸로 학습 기반의 교육 프로그램 풀잎스쿨(Flipped School) 런칭\n\n2015\n\n08\n\n모두의연구소 강남캠퍼스 설립\n\nBlog\n\n### 모두팸이 일하는 방식\n\n 스스로의 삶을 설계하는 모두의연구소 <br /> 성장형 ‘교육을 말하다’\n\n  Team Culture\n\n  ### 스스로의 삶을 설계하는 모두의연구소 성장형 ‘교육을 말하다’ 모두의연구소 <br /> 사내문화 스케치\n\n  Team Culture\n\n  ### 모두의연구소 사내문화 스케치 모두의연구소 <br /> DEI LAB 조직문화 기업 연구 사례\n\n  Team Culture\n\n  ### 모두의연구소 DEI LAB 조직문화 기업 연구 사례 AI학교 아이펠, <br /> 커뮤니티 그리고 성장의 비밀\n\n  Team Culture\n\n  ### AI학교 아이펠, 커뮤니티 그리고 성장의 비밀\n\n## 모두의연구소 아티클 소개\n\n### 언론 속의 모두의연구소\n\n### 김승일 모두의연구소 대표, 제5회 아이뉴스 DNA 공로상 수상 [...] ### 언론 속의 모두의연구소\n\n### 김승일 모두의연구소 대표, 제5회 아이뉴스 DNA 공로상 수상\n\n제5회 아이뉴스24 D·N·A 혁신상' 시상식이 18일 서울 용산구 그랜드 하얏트 서울에서 열렸다. 김 대표는 모두의연구소를 통해 누구나 하고 싶은 연구를 마음껏 할 수 있는 연구 문화와 연령·학벌 등에 차별 없는 AI 교육으로 국내 AI 발전과 인력 창출에 기여했다는 평가를 받는다.\n\n2024.12.18\n\n김승일 모두의연구소 대표, 제5회 아이뉴스 DNA 공로상 수상### 김승일 모두의연구소 대표, ‘2024 SW인재페스티벌’서 과기부 장관표창 수상\n\n인공지능(AI) 교육 전문 모두의연구소는 김승일 대표가 ‘2024 SW인재페스티벌’에서 과학기술정보통신부 장관 표창을 수상했다고 17일 밝혔다. 모두의연구소는 AI 연구 커뮤니티, AI-SW 인재 육성 사업, 기업 맞춤형 AI 교육 사업 등 다양한 분야를 담당하는 AI 교육 전문기업이다.\n\n2024.12.17\n\n김승일 모두의연구소 대표, ‘2024 SW인재페스티벌’서 과기부 장관표창 수상### 카카오엔터프라이즈-카카오임팩트-모두의연구소, 카카오클라우드로 더 나은 세상 조성 앞장\n\n아트코리아랩과 함께한 아트테크 랩 공유회 현장을 공유합니다. 상반기 랩의 활동 후기와 인공지능 예술 작품까지 다양한 소식을 확인해보세요!\n\n2024.10.02\n\n카카오엔터프라이즈-카카오임팩트-모두의연구소, 카카오클라우드로 더 나은 세상 조성 앞장### AI학교 아이펠, 글로벌 학회 ‘ICLR’에서 혁신 기술 논문 채택", "score": 0.8679453}, {"title": "모두의연구소 2026년 기업정보 - 직원수, 근무환경, 복리후생 등 | 잡코리아", "url": "https://www.jobkorea.co.kr/recruit/co_read/c/modulabs", "content": "Nice 평가정보\n\n## 고용현황\n\n### 채용 History\n\n212회의 채용 중\n\n정규직 채용은 152회입니다.\n\n|  |  |\n --- |\n| 경력 | 182 |\n| 신입,경력 | 30 |\n\n### 최근 3년간 채용 횟수\n\n최근 3년 기준\n\n### 사원수\n\n|  |  |  |  |\n ---  --- |\n| 2026 | 62명 | 100 | true |\n\n최근 1년 기준\n\n### 채용공고\n\n## 근무환경\n\n### 기업소개\n\n모두의연구소는 함께 배우고 성장하는 문화를 만들어 가기 위해 교육 서비스와 커뮤니티 서비스를 운영하고 있습니다.  \n[모두의연구소 service]  \nㆍAI / SW 등 다양한 기술 기반의 교육 서비스  \nㆍ다양한 주제들이 모인 커뮤니티 서비스  \n  \n모두의연구소는 교육 서비스와 커뮤니티 서비스를 통하여 기술과 지식을 나누며 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하며 누구나 자신의 연구와 성장을 이어갈 수 있는 환경을 만들어 가고자 합니다.  \n  \n`Share Value, Grow Together`는 모두의연구소의 슬로건입니다.  \n  \n지식을 공유하고 함께 성장하고 싶은 사람들! 바로 모두의연구소를 함께 만들어 갈 멋진 동료를 찾고 있습니다.   \n지금 바로 모두연에서 함께 성장해요!  \n  \n[모두연 읽어보기]  \nㆍ모두의연구소의 성장 스토리   \nㆍ교육을 말하다 1부 영상   \n  \n[모두의연구소 페이지]  \nㆍ모두의연구소 홈페이지   \nㆍ모두의연구소 채용 페이지 \n\n더보기;)\n\n### 복리후생\n\n연금·보험\n\n국민연금\n\n고용보험\n\n산재보험\n\n건강보험 [...] 본문 바로가기\n\n현재 브라우저의 보안 설정에 따라 복사가 허용되지 않습니다.  \n아래 URL 주소를 드래그 후 Ctrl+C를 눌러 복사하시기 바랍니다.\n\n닫기;)\n\n주소가 복사되었습니다.  \nCtrl+V를 눌러 붙여넣기 하세요.\n\n닫기;)\n\n# JOBKOREA\n\n전체 채용정보  신입공채 헤드헌팅 로그인\n\n모두의연구소\n\n관심기업 추가하고 채용소식 받기\n\n닫기;)\n\n공유;)\n\n페이스북) 즐겨찾기;) URL복사;)\n\n게시물\n\n## 기업 사진/동영상\n\n## 기업정보\n\n기업 상세 정보\n\n      | 산업 | IT컨설팅 | 사원수 | 62명 |\n| 기업구분 | 벤처기업 | 설립일 | 2015.12.05  ( ...
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "스토리 | 모두의연구소", "url": "https://modulabs.co.kr/modulabs-story", "content": "## 모두의연구소 미션 소개\n\nOur Mission\n\n### Share Value, Grow Together\n\n함께 지식을 공유하고 성장하는 연구 문화를 전파합니다\n\nOur Mission\n\nOur Value\n\n### 모두의연구소는 “경쟁이 아닌 상생의 힘” 을 믿습니다.\n\nOur Value\n\nbackground Quote\n\n모두의연구소는 지식을 나누고 함께 성장하는 커뮤니티형 교육을 통해 더 나은 미래를 만들고자 합니다. AI 시대, 100년 전처럼 주입식으로 가르치는 교육 방식은 점점 그 의미를 잃고 있습니다.   \n   \n 우리는 사람과 사람을 연결하여 함께 웃고, 배우고, 성장하는 과정을 소중히 여기며, 세상에 필요한 지식을 함께 나누는 세상을 꿈꿉니다.\n\n모두의연구소 대표 김승일\n\n브랜딩북 열어보기\n\n## 모두의연구소 비전 소개\n\n모두의연구소는\n\n### 오늘도 AI / SW 교육 혁신을 선도하고 있습니다\n\n 커뮤니티 연구원\n\n  커뮤니티 연구원\n\n  10,212\n\n  plus\n 스터디 활동 수\n\n  스터디 활동 수\n\n  949\n\n  plus\n 탑티어 논문\n\n  탑티어 논문\n\n  100\n\n  plus\n AI / SW 졸업생\n\n  AI / SW 졸업생\n\n  1,258\n\n  plus\n\n2024\n\n2024\n\n05\n\nAI 미래포럼 공동의장단 대표 선정\n\n12\n\n과학기술정보통신부 장관 표창\n\n2023\n\n2023\n\n09\n\n2023 직업능력의 달 기념 대통령 표창\n\n10\n\nSW교육 오름캠프 교육 런칭\n\n2022\n\n2022\n\n02\n\n70억 투자 유치 (KB인베스트먼트, 대교인베스트먼트)\n\n06 [...] 10\n\nAI 혁신학교 아이펠(AIFFEL) 온라인 캠퍼스 개소\n\n2021\n\n02\n\nAI 혁신학교 아이펠(AIFFEL) 인천 캠퍼스 개소\n\n10\n\nKOREA AI STARTUP 100 선정\n\n12\n\nAI 혁신학교 아이펠(AIFFEL) 부산, 울산, 대구 캠퍼스 개소\n\n2020\n\n07\n\nAI 혁신학교 아이펠(AIFFEL) 강남 캠퍼스 개소\n\n12\n\nAI 혁신학교 아이펠(AIFFEL) 대전 및 문래 캠퍼스 개소\n\n2017\n\n01\n\n모두의연구소 기업교육 시작\n\n10\n\n국내 최초 거꾸로 학습 기반의 교육 프로그램 풀잎스쿨(Flipped School) 런칭\n\n2015\n\n08\n\n모두의연구소 강남캠퍼스 설립\n\nBlog\n\n### 모두팸이 일하는 방식\n\n 스스로의 삶을 설계하는 모두의연구소 <br /> 성장형 ‘교육을 말하다’\n\n  Team Culture\n\n  ### 스스로의 삶을 설계하는 모두의연구소 성장형 ‘교육을 말하다’ 모두의연구소 <br /> 사내문화 스케치\n\n  Team Culture\n\n  ### 모두의연구소 사내문화 스케치 모두의연구소 <br /> DEI LAB 조직문화 기업 연구 사례\n\n  Team Culture\n\n  ### 모두의연구소 DEI LAB 조직문화 기업 연구 사례 AI학교 아이펠, <br /> 커뮤니티 그리고 성장의 비밀\n\n  Team Culture\n\n  ### AI학교 아이펠, 커뮤니티 그리고 성장의 비밀\n\n## 모두의연구소 아티클 소개\n\n### 언론 속의 모두의연구소\n\n### 김승일 모두의연구소 대표, 제5회 아이뉴스 DNA 공로상 수상 [...] ### 언론 속의 모두의연구소\n\n### 김승일 모두의연구소 대표, 제5회 아이뉴스 DNA 공로상 수상\n\n제5회 아이뉴스24 D·N·A 혁신상' 시상식이 18일 서울 용산구 그랜드 하얏트 서울에서 열렸다. 김 대표는 모두의연구소를 통해 누구나 하고 싶은 연구를 마음껏 할 수 있는 연구 문화와 연령·학벌 등에 차별 없는 AI 교육으로 국내 AI 발전과 인력 창출에 기여했다는 평가를 받는다.\n\n2024.12.18\n\n김승일 모두의연구소 대표, 제5회 아이뉴스 DNA 공로상 수상### 김승일 모두의연구소 대표, ‘2024 SW인재페스티벌’서 과기부 장관표창 수상\n\n인공지능(AI) 교육 전문 모두의연구소는 김승일 대표가 ‘2024 SW인재페스티벌’에서 과학기술정보통신부 장관 표창을 수상했다고 17일 밝혔다. 모두의연구소는 AI 연구 커뮤니티, AI-SW 인재 육성 사업, 기업 맞춤형 AI 교육 사업 등 다양한 분야를 담당하는 AI 교육 전문기업이다.\n\n2024.12.17\n\n김승일 모두의연구소 대표, ‘2024 SW인재페스티벌’서 과기부 장관표창 수상### 카카오엔터프라이즈-카카오임팩트-모두의연구소, 카카오클라우드로 더 나은 세상 조성 앞장\n\n아트코리아랩과 함께한 아트테크 랩 공유회 현장을 공유합니다. 상반기 랩의 활동 후기와 인공지능 예술 작품까지 다양한 소식을 확인해보세요!\n\n2024.10.02\n\n카카오엔터프라이즈-카카오임팩트-모두의연구소, 카카오클라우드로 더 나은 세상 조성 앞장### AI학교 아이펠, 글로벌 학회 ‘ICLR’에서 혁신 기술 논문 채택", "score": 0.8679453}, {"title": "모두의연구소 2026년 기업정보 - 직원수, 근무환경, 복리후생 등 | 잡코리아", "url": "https://www.jobkorea.co.kr/recruit/co_read/c/modulabs", "content": "Nice 평가정보\n\n## 고용현황\n\n### 채용 History\n\n212회의 채용 중\n\n정규직 채용은 152회입니다.\n\n|  |  |\n --- |\n| 경력 | 182 |\n| 신입,경력 | 30 |\n\n### 최근 3년간 채용 횟수\n\n최근 3년 기준\n\n### 사원수\n\n|  |  |  |  |\n ---  --- |\n| 2026 | 62명 | 100 | true |\n\n최근 1년 기준\n\n### 채용공고\n\n## 근무환경\n\n### 기업소개\n\n모두의연구소는 함께 배우고 성장하는 문화를 만들어 가기 위해 교육 서비스와 커뮤니티 서비스를 운영하고 있습니다.  \n[모두의연구소 service]  \nㆍAI / SW 등 다양한 기술 기반의 교육 서비스  \nㆍ다양한 주제들이 모인 커뮤니티 서비스  \n  \n모두의연구소는 교육 서비스와 커뮤니티 서비스를 통하여 기술과 지식을 나누며 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하며 누구나 자신의 연구와 성장을 이어갈 수 있는 환경을 만들어 가고자 합니다.  \n  \n`Share Value, Grow Together`는 모두의연구소의 슬로건입니다.  \n  \n지식을 공유하고 함께 성장하고 싶은 사람들! 바로 모두의연구소를 함께 만들어 갈 멋진 동료를 찾고 있습니다.   \n지금 바로 모두연에서 함께 성장해요!  \n  \n[모두연 읽어보기]  \nㆍ모두의연구소의 성장 스토리   \nㆍ교육을 말하다 1부 영상   \n  \n[모두의연구소 페이지]  \nㆍ모두의연구소 홈페이지   \nㆍ모두의연구소 채용 페이지 \n\n더보기;)\n\n### 복리후생\n\n연금·보험\n\n국민연금\n\n고용보험\n\n산재보험\n\n건강보험 [...] 본문 바로가기\n\n현재 브라우저의 보안 설정에 따라 복사가 허용되지 않습니다.  \n아래 URL 주소를 드래그 후 Ctrl+C를 눌러 복사하시기 바랍니다.\n\n닫기;)\n\n주소가 복사되었습니다.  \nCtrl+V를 눌러 붙여넣기 하세요.\n\n닫기;)\n\n# JOBKOREA\n\n전체 채용정보  신입공채 헤드헌팅 로그인\n\n모두의연구소\n\n관심기업 추가하고 채용소식 받기\n\n닫기;)\n\n공유;)\n\n페이스북) 즐겨찾기;) URL복사;)\n\n게시물\n\n## 기업 사진/동영상\n\n## 기업정보\n\n기업 상세 정보\n\n      | 산업 | IT컨설팅 | 사원수 | 62명 |\n| 기업구분 | 벤처기업 | 설립일 | 2015.12.05  ( ...
# ================================== Ai Message ==================================
# Tool Calls:
#   write_pdf (call_byP00Lf3IiZycX6PJxVU4OuD)
#  Call ID: call_byP00Lf3IiZycX6PJxVU4OuD
#   Args:
#     content: 모두의연구소는 AI 및 소프트웨어 교육 혁신을 선도하는 기관으로, 지식을 공유하고 함께 성장하는 커뮤니티형 교육을 통해 더 나은 미래를 만들고자 합니다. 모두의연구소는 경쟁이 아닌 상생의 힘을 믿으며, 사람과 사람을 연결하여 함께 웃고, 배우고, 성장하는 과정을 소중히 여깁니다.\n\n모두의연구소는 다양한 AI 및 SW 교육 프로그램을 운영하며, AI 연구 커뮤니티, AI-SW 인재 육성 사업, 기업 맞춤형 AI 교육 사업 등 다양한 분야를 담당하는 AI 교육 전문기업입니다.\n\n주요 연혁:\n- 2015년 8월: 모두의연구소 강남캠퍼스 설립\n- 2017년 1월: 기업교육 시작\n- 2020년 7월: AI 혁신학교 아이펠(AIFFEL) 강남 캠퍼스 개소\n- 2021년 10월: KOREA AI STARTUP 100 선정\n- 2022년 2월: 70억 투자 유치\n- 2023년 9월: 직업능력의 달 기념 대통령 표창\n- 2024년 12월: 과학기술정보통신부 장관 표창\n\n모두의연구소는 AI 시대에 맞춰 주입식 교육 방식에서 벗어나, 자율적이고 창의적인 연구 환경을 제공하며, 연구자들이 서로 교류하고 협력할 수 있는 환경을 조성하고 있습니다. 이를 통해 다양한 배경의 연구자들이 혁신적인 연구 성과를 창출할 수 있도록 지원하고 있습니다.
#     filename: 모두의연구소_레포트.pdf
# ================================= Tool Message =================================
# Name: write_pdf
#
# 모두의연구소_레포트.pdf 저장 완료
# ================================= Tool Message =================================
# Name: write_pdf
#
# 모두의연구소_레포트.pdf 저장 완료

# %%
config = reset_config()

query = "'모두의연구소_레포트.pdf'라는 파일 삭제해줘"

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# '모두의연구소_레포트.pdf'라는 파일 삭제해줘
# ================================ Human Message =================================
#
# '모두의연구소_레포트.pdf'라는 파일 삭제해줘
# ================================== Ai Message ==================================
# Tool Calls:
#   file_delete (call_WE7Gl2RbKpkag1qdNTSYRTbU)
#  Call ID: call_WE7Gl2RbKpkag1qdNTSYRTbU
#   Args:
#     file_path: 모두의연구소_레포트.pdf
# ================================= Tool Message =================================
# Name: file_delete
#
# File deleted successfully: 모두의연구소_레포트.pdf.
# ================================= Tool Message =================================
# Name: file_delete
#
# File deleted successfully: 모두의연구소_레포트.pdf.
